# %%
printf("HoneyBadger")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 printf("HoneyBadger")
#
# NameError: name 'printf' is not defined

# %%
print("hello"
# Out:
#   Cell In[7], line 1
#     print("hello"
#                  ^
# SyntaxError: incomplete input

# %%
if name=="HoneyBadger":
print("HoneyBadger")
# Out:
#   Cell In[1], line 2
#     print("HoneyBadger")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
print("You are at HoneyBadger.io")
   print("We are discussing errors in Python.")
# Out:
#   Cell In[3], line 2
#     print("You are learning about errors in Python.")
#     ^
# IndentationError: unexpected indent

# %%
print("HoneyBadger)
# Out:
#   Cell In[8], line 1
#     print("HoneyBadger)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
name="""You are at HoneyBadger.io.
We are discussing errors in Python.""
# Out:
#   Cell In[10], line 1
#     name="""You are at HoneyBadger.io.
#          ^
# SyntaxError: incomplete input

# %%
data = [1, 2, 3
# Out:
#   Cell In[11], line 1
#     data = [1, 2, 3
#                    ^
# SyntaxError: incomplete input

# %%
name="HoneyBadger"
if name="HoneyBadger":
   print("Hi")
# Out:
#   Cell In[14], line 2
#     if name="HoneyBadger":
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
5=x
# Out:
#   Cell In[15], line 1
#     5=x
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
